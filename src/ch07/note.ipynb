# %% [markdown]
# # 7장 노트 정리
#
#
# |학과|학번|이름|작성일|
# |----|----|----|----|
# |컴퓨터공학과|202111615|함기은|2025-09-30|

# %% [markdown]
# # 7장 모듈
#
# ## 모듈 설치와 불러오기
#
# ### 모듈
#
# ### 모듈 사용하기
#
# ### 모듈 불러오기
#
# ## 사용자 정의 모듈
#
# * 사용자 정의 모듈 만들기
#
#
# * 사용자 정의 모듈의 사용
#
#
# ## 유용한 모듈들 <a class="anchor" id="유용한-모듈들"></a>
#
# * sys 모듈
#
# * * sys.argv 속성
#
# * random 모듈
#
# * math 모듈
#
# * time 모듈
#
# * calendar 모듈
#
# * enum 모듈
